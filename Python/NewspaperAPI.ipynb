# %% [markdown]
# # Necessary Steps

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd

# %%
cd /content/drive/MyDrive/MediaCloud
# Out:
# /content/drive/MyDrive/MediaCloud

# %%
pwd = os.getcwd()
pwd
# Out:
# '/content/drive/MyDrive/MediaCloud'

# %% [markdown]
# # Equal Division of Newspapers Based on Years

# %%
mediacloud_data = pd.read_csv(os.path.join(pwd, "Data/Annual_Budget_Indian_National_2014-2024.csv"))

# %%
articles = 150 # Number of articles you want to download for each year

# %%
# Convert the 'publish_date' column to datetime
mediacloud_data['publish_date'] = pd.to_datetime(mediacloud_data['publish_date'])

# Extract the year from the 'publish_date' column
mediacloud_data['year'] = mediacloud_data['publish_date'].dt.year


output_folder = os.path.join(pwd, "Data/YearWise_Data")
os.makedirs(output_folder, exist_ok=True)

# Loop through each unique year and process the data
for year in mediacloud_data['year'].unique():
    # Filter the dataframe for the current year
    data_year = mediacloud_data[mediacloud_data['year'] == year]

    # Randomly sample 150 rows if there are more than 150 articles, otherwise take all
    data_sampled = data_year.sample(n=articles, random_state=42) if len(data_year) > 150 else data_year

    # Save the sampled dataframe to a CSV file
    output_path = os.path.join(output_folder, f'data_{year}.csv')
    data_sampled.to_csv(output_path, index=False)

    print(f"Saved {len(data_sampled)} articles for the year {year} to {output_path}")
# Out:
# Saved 150 articles for the year 2021 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2021.csv
# Saved 150 articles for the year 2019 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2019.csv
# Saved 150 articles for the year 2020 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2020.csv
# Saved 100 articles for the year 2017 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2017.csv
# Saved 104 articles for the year 2018 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2018.csv
# Saved 150 articles for the year 2016 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2016.csv
# Saved 83 articles for the year 2014 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2014.csv
# Saved 27 articles for the year 2012 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2012.csv
# Saved 150 articles for the year 2015 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2015.csv
# Saved 54 articles for the year 2013 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2013.csv
# Saved 6 articles for the year 2010 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2010.csv
# Saved 150 articles for the year 2022 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2022.csv
# Saved 24 articles for the year 2011 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2011.csv
# Saved 150 articles for the year 2023 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2023.csv
# Saved 150 articles for the year 2024 to /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2024.csv

# %% [markdown]
# > **As of now I have manually kept only data of years 2020, 2021, 2022, 2023, and 2024**

# %% [markdown]
# # Parse the data for each individual year

# %%
# !pip install newspaper3k
# Out:
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.12.3)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (10.4.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (6.0.2)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.9.4)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.8.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.32.3)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.1.2-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 48.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.8.2)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2024.8.30)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.16.1)
# Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 15.8 MB/s eta 0:00:00
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 7.0 MB/s eta 0:00:00
# Downloading tldextract-5.1.2-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 7.4 MB/s eta 0:00:00
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13540 sha256=322720c1ef95a6486d04c7b44f869ed27d3a0803346553745a5be480ae316296
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3342 sha256=02f980adb716e1810b497db6ed29fb78e7f35721b7933989bb45964394bd747a
#   Stored in directory: /root/.cache/pip/wheels/97/02/e7/a1ff1760e12bdbaab0ac824fae5c1bc933e41c4ccd6a8f8edb
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398380 sha256=11859a8edc6edda587827704a93a78a03e2c5ce70fac1a662086bcd51307d5f5
#   Stored in directory: /root/.cache/pip/wheels/7a/c4/0c/12a9a314ecac499456c4c3b2fcc2f635a3b45a39dfbd240299
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=247ba1805235e44eb4ac1d489996f76b9f80afa7856547a45a25a7410f9da0c7
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.2.0 feedfinder2-0.0.4 feedparser-6.0.11 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-2.1.0 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.1.2

# %%
import os
import time
import pandas as pd
from newspaper import Article
import nltk
from requests.exceptions import HTTPError, ConnectionError
import urllib3

# %%
pwd
# Out:
# '/content/drive/MyDrive/MediaCloud'

# %%
nltk.download('punkt')

source_folder = os.path.join(pwd, 'Data/YearWise_Data')

destination_folder = os.path.join(pwd, 'Data/Parsed_YearWise_Data')
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Function to process a single CSV file
def process_csv_file(file_path, destination_folder):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Add empty columns for parsed data
    df['parsed_title'] = ''
    df['parsed_authors'] = ''
    df['parsed_publish_date'] = ''
    df['parsed_text'] = ''
    df['parsed_category'] = ''
    df['parsed_summary'] = ''
    df['parsed_keywords'] = ''

    # Record the start time
    start_time = time.time()

    # Loop through each URL in the CSV
    for index, row in df.iterrows():
        url = row['url']  # Assuming the column containing URLs is 'url'

        try:
            # Validate URL format
            if not url.startswith('http'):
                raise ValueError(f"Invalid URL: {url}")

            # Download and parse the article
            article = Article(url, language="en")
            article.download()
            article.parse()

            # Store the parsed data in the respective columns
            df.at[index, 'parsed_title'] = article.title
            df.at[index, 'parsed_authors'] = ', '.join(article.authors)
            df.at[index, 'parsed_publish_date'] = article.publish_date
            df.at[index, 'parsed_text'] = article.text

            # Perform NLP operations
            article.nlp()
            df.at[index, 'parsed_keywords'] = ', '.join(article.keywords)
            df.at[index, 'parsed_summary'] = article.summary

            # Extract category from the URL
            category_parts = url.split('/')
            if len(category_parts) > 3:  # Assuming category is in the fourth segment
                df.at[index, 'parsed_category'] = category_parts[3]
            else:
                df.at[index, 'parsed_category'] = None

        except HTTPError as http_err:
            print(f"HTTP error occurred: {http_err} for URL: {url}")
        except ConnectionError as conn_err:
            print(f"Connection error occurred: {conn_err} for URL: {url}")
        except urllib3.exceptions.MaxRetryError as retry_err:
            print(f"Max retries exceeded for URL: {url}")
        except ValueError as val_err:
            print(f"Value error: {val_err}")
        except Exception as e:
            print(f"Failed to process URL: {url} with error: {e}")

        # Adding a small delay to avoid overwhelming the server with requests
        time.sleep(1)

    # Record the end time
    end_time = time.time()

    # Calculate the total time taken
    execution_time = end_time - start_time
    print(f"Total time taken to process {file_path}: {execution_time} seconds")

    # Get the file name from the original path
    file_name = os.path.basename(file_path)

    # Create the destination file name (e.g., Parsed_2020.csv)
    destination_file_path = os.path.join(destination_folder, f"Parsed_{file_name}")

    # Save the updated DataFrame to the destination folder
    df.to_csv(destination_file_path, index=False)

# Loop through each CSV file in the source folder
for file_name in os.listdir(source_folder):
    # Process only CSV files
    if file_name.endswith('.csv'):
        file_path = os.path.join(source_folder, file_name)
        print(f"Processing {file_path}...")

        # Call the function to process each CSV
        process_csv_file(file_path, destination_folder)

print("All files processed successfully!")
# Out:
# Processing /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2021.csv...
# Failed to process URL: http://www.indiasnews.net/news/267672727/16-opposition-parties-to-boycott-presidential-address with error: You must `download()` an article first!
# Failed to process URL: http://www.indiasnews.net/news/272063928/states-demand-gst-compensation-for-another-5-years with error: You must `download()` an article first!
# Failed to process URL: http://www.businessworld.in/article/Healthcare-attains-foremost-priority-for-the-first-time-in-Union-Budget-says-Gandharv-Roy-Medica-Group-of-Hospitals/09-02-2021-375426 with error: You must `download()` an article first!
# Failed to process URL: https://www.businessworld.in/article/Impact-Of-Government-Policies-On-The-Auto-Mobile-Industry/26-03-2021-384969 with error: You must `download()` an article first!
# Failed to process URL: http://www.businessworld.in/article/Indian-Shares-Rise-Ahead-Of-Budget/01-02-2021-372198 with error: You must `download()` an article first!
# Failed to process URL: https://www.sify.com/news/16-opposition-parties-to-boycott-presidential-address-to-parliament-demand-probe-into-r-day-violence-news-national-vb2jaihdeajij.html with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.sify.com/news/16-opposition-parties-to-boycott-presidential-address-to-parliament-demand-probe-into-r-day-violence-news-national-vb2jaihdeajij.html on URL https://www.sify.com/news/16-opposition-parties-to-boycott-presidential-address-to-parliament-demand-probe-into-r-day-violence-news-national-vb2jaihdeajij.html
# Failed to process URL: http://www.businessworld.in/article/Announcement-Of-Voluntary-Scrappage-Policy-In-Union-Budget-A-Step-In-Right-Direction-M-M/02-02-2021-372668 with error: You must `download()` an article first!
# Failed to process URL: https://www.sify.com/news/social-media-abuzz-over-monument-for-former-foe-of-kerala-cpi-m-news-national-vgfhkuceehbij.html with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.sify.com/news/social-media-abuzz-over-monument-for-former-foe-of-kerala-cpi-m-news-national-vgfhkuceehbij.html on URL https://www.sify.com/news/social-media-abuzz-over-monument-for-former-foe-of-kerala-cpi-m-news-national-vgfhkuceehbij.html
# Failed to process URL: http://www.businessworld.in/article/Budget-will-be-in-accordance-with-people-s-expectations-says-Anurag-Thakur/01-02-2021-372176 with error: You must `download()` an article first!
# Failed to process URL: http://www.indiasnews.net/news/269718925/piyush-goyal-calls-for-adding-more-participants-in-gem with error: You must `download()` an article first!
# Failed to process URL: https://www.newsclick.in/As-Bank-Employees-Strike-Work-Farmers-TUs-Join-Protest-Against-Privatisation with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.newsclick.in/As-Bank-Employees-Strike-Work-Farmers-TUs-Join-Protest-Against-Privatisation on URL https://www.newsclick.in/As-Bank-Employees-Strike-Work-Farmers-TUs-Join-Protest-Against-Privatisation
# Failed to process URL: https://www.oneindia.com/india/7th-pay-commission-what-the-new-wage-code-will-mean-to-cg-employees-3224571.html with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.oneindia.com/india/7th-pay-commission-what-the-new-wage-code-will-mean-to-cg-employees-3224571.html on URL https://www.oneindia.com/india/7th-pay-commission-what-the-new-wage-code-will-mean-to-cg-employees-3224571.html
# Failed to process URL: http://www.businessworld.in/article/Budget-21-22-Prioritising-Health-for-all-Citizens/15-02-2021-377942 with error: You must `download()` an article first!
# Failed to process URL: https://www.financialexpress.com/money/insurance/finance-ministry-to-infuse-rs-3000-cr-in-general-insurance-companies-this-quarter/2194641/ with error: Article `download()` failed with HTTPSConnectionPool(host='www.financialexpress.com', port=443): Read timed out. (read timeout=7) on URL https://www.financialexpress.com/money/insurance/finance-ministry-to-infuse-rs-3000-cr-in-general-insurance-companies-this-quarter/2194641/
# Failed to process URL: https://www.financialexpress.com/economy/rbi-raises-retail-inflation-projection-for-fy22-to-5-7-pc/2305575/ with error: Article `download()` failed with HTTPSConnectionPool(host='www.financialexpress.com', port=443): Read timed out. (read timeout=7) on URL https://www.financialexpress.com/economy/rbi-raises-retail-inflation-projection-for-fy22-to-5-7-pc/2305575/
# Failed to process URL: https://www.sify.com/news/final-stage-of-budget-2021-22-commences-with-halwa-ceremony-news-national-vbxm4uecbidcf.html with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.sify.com/news/final-stage-of-budget-2021-22-commences-with-halwa-ceremony-news-national-vbxm4uecbidcf.html on URL https://www.sify.com/news/final-stage-of-budget-2021-22-commences-with-halwa-ceremony-news-national-vbxm4uecbidcf.html
# Failed to process URL: https://www.sify.com/news/cibil-rating-shouldnt-be-mandatory-for-street-vendors-for-loans-mp-cm-urges-sitharaman-news-national-vbpqahciggdah.html with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.sify.com/news/cibil-rating-shouldnt-be-mandatory-for-street-vendors-for-loans-mp-cm-urges-sitharaman-news-national-vbpqahciggdah.html on URL https://www.sify.com/news/cibil-rating-shouldnt-be-mandatory-for-street-vendors-for-loans-mp-cm-urges-sitharaman-news-national-vbpqahciggdah.html
# Failed to process URL: https://www.firstpost.com/india/budget-2021-highlights-science-ministries-are-allocated-funds-over-rs-15000-crore-9262541.html with error: Article `download()` failed with 404 Client Error: Not Found for url: https://www.firstpost.com/india/budget-2021-highlights-science-ministries-are-allocated-funds-over-rs-15000-crore-9262541.html on URL https://www.firstpost.com/india/budget-2021-highlights-science-ministries-are-allocated-funds-over-rs-15000-crore-9262541.html
# Total time taken to process /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2021.csv: 331.2107253074646 seconds
# Processing /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2020.csv...
# Failed to process URL: http://www.businessworld.in/article/India-holds-first-ever-Ind-SAT-exam-under-Study-in-India-programme/23-07-2020-300725 with error: You must `download()` an article first!
# Failed to process URL: https://www.tribuneindia.com/news/himachal-tribune/a-feat-of-digital-transformation-55261 with error: Article `download()` failed with 404 Client Error: Not Found for url: https://www.tribuneindia.com/news/himachal-tribune/a-feat-of-digital-transformation-55261 on URL https://www.tribuneindia.com/news/himachal-tribune/a-feat-of-digital-transformation-55261
# Failed to process URL: http://newsonair.com/Main-News-Details.aspx?id=411070 with error: Article `download()` failed with HTTPSConnectionPool(host='newsonair.gov.inmain-news-details.aspx', port=443): Max retries exceeded with url: /?id=411070 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a0b89d458a0>: Failed to resolve 'newsonair.gov.inmain-news-details.aspx' ([Errno -2] Name or service not known)")) on URL http://newsonair.com/Main-News-Details.aspx?id=411070
# Failed to process URL: http://www.businessworld.in/article/Auto-Cos-Need-To-Map-Vulnerabilities-Realign-Supply-Chains-To-Meet-Challenges-Report/21-12-2020-356354 with error: You must `download()` an article first!
# Failed to process URL: http://www.businessworld.in/article/Can-the-Quantum-of-good-news-be-any-better-for-2021-/14-12-2020-353640 with error: You must `download()` an article first!
# Failed to process URL: http://www.businessworld.in/article/FM-Sitharaman-Proposes-Rs-2-500-Crore-For-Tourism-In-2020-21-Eight-New-Museums/01-02-2020-183232 with error: You must `download()` an article first!
# Failed to process URL: https://dailynews360.patrika.com/budget/union-budget-2020-finance-minister-morarji-desai-presented-budget-10-with-record-45951.html with error: Article `download()` failed with HTTPSConnectionPool(host='dailynews360.patrika.com', port=443): Max retries exceeded with url: /budget/union-budget-2020-finance-minister-morarji-desai-presented-budget-10-with-record-45951.html (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'dailynews360.patrika.com'. (_ssl.c:1007)"))) on URL https://dailynews360.patrika.com/budget/union-budget-2020-finance-minister-morarji-desai-presented-budget-10-with-record-45951.html
# Failed to process URL: http://www.businessworld.in/article/BPCL-Privatisation-Bid-Closes-On-Monday-All-Eyes-On-Reliance/16-11-2020-343059 with error: You must `download()` an article first!
# Failed to process URL: https://www.firstpost.com/budget-2020/ with error: Article `download()` failed with 503 Server Error: Service Unavailable for url: https://www.firstpost.com/budget-2020/ on URL https://www.firstpost.com/budget-2020/
# Total time taken to process /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2020.csv: 271.3929138183594 seconds
# Processing /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2022.csv...
# Failed to process URL: https://www.businessworld.in/article/Emerging-Businesses-To-Watch-Out-For-/16-09-2022-446846 with error: You must `download()` an article first!
# Failed to process URL: https://www.newsclick.in/eminent-economists-recommend-pensions-maternity-benefits-next-budget with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.newsclick.in/eminent-economists-recommend-pensions-maternity-benefits-next-budget on URL https://www.newsclick.in/eminent-economists-recommend-pensions-maternity-benefits-next-budget
# Failed to process URL: https://telugu.oneindia.com/news/india/union-budget-2022-union-minister-nirmala-sitharaman-ditches-red-chooses-an-orange-pochampally-311550.html with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://telugu.oneindia.com/news/india/union-budget-2022-union-minister-nirmala-sitharaman-ditches-red-chooses-an-orange-pochampally-311550.html on URL https://telugu.oneindia.com/news/india/union-budget-2022-union-minister-nirmala-sitharaman-ditches-red-chooses-an-orange-pochampally-311550.html
# Failed to process URL: https://www.businessworld.in/article/Icra-Expects-Enhanced-Support-For-Waterways-Logistics-Sectors-Amid-Budget-2022-/24-01-2022-418621 with error: You must `download()` an article first!
# Failed to process URL: https://www.businessworld.in/article/Ground-Report-Economy-Is-Growing-But-COVID-19-Still-Haunting-Small-Town-Street-Vendors-/28-01-2022-418942 with error: You must `download()` an article first!
# Failed to process URL: https://www.businessworld.in/article/Strengthening-Atmanirbharta-Generating-Employment/08-02-2022-419946 with error: You must `download()` an article first!
# Failed to process URL: http://www.indiasnews.net/news/273128115/budget-2023-24-sitharaman-chairs-consultation-with-farm-sector-experts with error: You must `download()` an article first!
# Failed to process URL: http://www.indiasnews.net/news/272171037/budget-session-of-parliament-to-commence-on-january-31 with error: You must `download()` an article first!
# Failed to process URL: https://www.businessworld.in/article/Budget-2022-FADA-Seeks-Lowering-Of-GST-On-Two-Wheelers-And-Used-Cars-/17-01-2022-417937 with error: You must `download()` an article first!
# Total time taken to process /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2022.csv: 335.5000374317169 seconds
# Processing /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2023.csv...
# Failed to process URL: http://www.indiasnews.net/news/273596740/way-india-pharma-sector-gained-trust-during-covid-19-was-unprecedented-pm-modi with error: You must `download()` an article first!
# Failed to process URL: http://www.indiasnews.net/news/273656798/world-water-day-india-provided-tap-connections-to-over-11-crore-rural-households with error: You must `download()` an article first!
# Failed to process URL: https://www.newsclick.in/electoral-bonds-no-solution-illegal-political-funding with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.newsclick.in/electoral-bonds-no-solution-illegal-political-funding on URL https://www.newsclick.in/electoral-bonds-no-solution-illegal-political-funding
# Failed to process URL: https://www.newsclick.in/anaemia-mukt-bharat-distant-dream-due-weak-public-health-sector-budget-cuts with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.newsclick.in/anaemia-mukt-bharat-distant-dream-due-weak-public-health-sector-budget-cuts on URL https://www.newsclick.in/anaemia-mukt-bharat-distant-dream-due-weak-public-health-sector-budget-cuts
# Failed to process URL: http://www.indiasnews.net/news/273874791/weddingwire-india-hosts-an-industry-first-wedding-conference-2023-in-the-capital with error: You must `download()` an article first!
# Failed to process URL: https://www.newindianexpress.com/business/2023/feb/01/online-gaming-government-to-clarify-on-taxation-2543411.html with error: Article `download()` failed with 404 Client Error: Not Found for url: https://www.newindianexpress.com/business/2023/feb/01/online-gaming-government-to-clarify-on-taxation-2543411.html on URL https://www.newindianexpress.com/business/2023/feb/01/online-gaming-government-to-clarify-on-taxation-2543411.html
# Failed to process URL: https://newsonair.com/2023/01/05/vehicle-scrappage-policy-11-states-uts-join-the-national-single-window-system/ with error: Article `download()` failed with HTTPSConnectionPool(host='newsonair.com', port=443): Max retries exceeded with url: /2023/01/05/vehicle-scrappage-policy-11-states-uts-join-the-national-single-window-system/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'newsonair.com'. (_ssl.c:1007)"))) on URL https://newsonair.com/2023/01/05/vehicle-scrappage-policy-11-states-uts-join-the-national-single-window-system/
# Failed to process URL: https://newsonair.com/2023/04/06/sports-authority-of-india-integrates-khelo-india-games-certificates-with-digilocker/ with error: Article `download()` failed with HTTPSConnectionPool(host='newsonair.com', port=443): Max retries exceeded with url: /2023/04/06/sports-authority-of-india-integrates-khelo-india-games-certificates-with-digilocker/ (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'newsonair.com'. (_ssl.c:1007)"))) on URL https://newsonair.com/2023/04/06/sports-authority-of-india-integrates-khelo-india-games-certificates-with-digilocker/
# Total time taken to process /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2023.csv: 315.04130601882935 seconds
# Processing /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2024.csv...
# Failed to process URL: https://www.businessworld.in/article/Vote-on-account-Before-The-Big-Vote/20-01-2024-507007/ with error: You must `download()` an article first!
# Failed to process URL: https://www.businessworld.in/article/Indian-Stock-Indices-Edged-Marginally-Lower-At-Opening-Bell-/30-01-2024-508121/ with error: You must `download()` an article first!
# Failed to process URL: https://www.oneindia.com/india/budget-reactions-go-viral-as-funny-memes-flood-social-media-3740463.html with error: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.oneindia.com/india/budget-reactions-go-viral-as-funny-memes-flood-social-media-3740463.html on URL https://www.oneindia.com/india/budget-reactions-go-viral-as-funny-memes-flood-social-media-3740463.html
# Failed to process URL: https://www.inkhabar.com/national/union-budget-2024-expectations-common-mans-expectations-from-nirmala-sitharaman-regarding-the-budget with error: Article `download()` failed with ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')) on URL https://www.inkhabar.com/national/union-budget-2024-expectations-common-mans-expectations-from-nirmala-sitharaman-regarding-the-budget
# Total time taken to process /content/drive/MyDrive/MediaCloud/Data/YearWise_Data/data_2024.csv: 293.504940032959 seconds
# All files processed successfully!

# %% [markdown]
# # Remove Those Articles Where Text Was Not Parsed Somehow

# %%
pwd
# Out:
# '/content/drive/MyDrive/MediaCloud'

# %%
parsed_data_folder = os.path.join(pwd, 'Data/Parsed_YearWise_Data')

# %%
def clean_csv_file(file_path):

    dff = pd.read_csv(file_path)
    dff_cleaned = dff.dropna(subset=['parsed_text'])
    dff_cleaned.to_csv(file_path, index=False)


for file_name in os.listdir(parsed_data_folder):
    # Process only CSV files
    if file_name.endswith('.csv'):
        file_path = os.path.join(parsed_data_folder, file_name)
        print(f"Cleaning {file_path}...")

        # Call the function to clean each CSV
        clean_csv_file(file_path)

print("All files cleaned successfully!")
# Out:
# Cleaning /content/drive/MyDrive/MediaCloud/Data/Parsed_YearWise_Data/Parsed_data_2021.csv...
# Cleaning /content/drive/MyDrive/MediaCloud/Data/Parsed_YearWise_Data/Parsed_data_2020.csv...
# Cleaning /content/drive/MyDrive/MediaCloud/Data/Parsed_YearWise_Data/Parsed_data_2022.csv...
# Cleaning /content/drive/MyDrive/MediaCloud/Data/Parsed_YearWise_Data/Parsed_data_2023.csv...
# Cleaning /content/drive/MyDrive/MediaCloud/Data/Parsed_YearWise_Data/Parsed_data_2024.csv...
# All files cleaned successfully!
