# %%
import pandas as pd

# %%
df = pd.read_csv("/home/vidur/mediagraph/Python/output_final.csv")

# Converting the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

filtered_df = df[(df['Date'] >= '2020-08-01') & (df['Date'] < '2021-02-01')]

filtered_df
# Out:
#       Unnamed: 0                                              Title  \
# 1605        1605  Forest officials transferred after farm owner’...
# 1606        1606          Farmers begin symbolic stir at MLA houses
# 1607        1607  Goa govt clears dues of support price to sugar...
# 1608        1608  Dairy agitation comes to a boil, farmers spill...
# 1609        1609              Sandalwood goes farming to beat blues
# ...          ...                                                ...
# 4309        4309  ‘Republic Day events a temporary setback, farm...
# 4310        4310  Doctors flay attack on medical team during tra...
# 4311        4311            Mango farmers go organic to boost yield
# 4312        4312  Agri min promises to raise limit of farm-loan ...
# 4313        4313  Farmers’ protest: Man under boot now image of ...
#
#            Date                                               Text  \
# 1605 2020-08-01  KOTTAYAM: The police investigation team has fo...
# ...

# %%
filtered_df.to_csv("/home/vidur/mediagraph/Python/FarmersProtest2020.csv", index=False)
